# %%
from nltk.corpus import wordnet as wn
lemmas_in_WordNet = wn.words()


#i=0
#for ss in wn.all_synsets():
#    print ss
#    i=i+1
#print ss.definition()

lemmas_in_wordnet = set(i for i in wn.words())
len(lemmas_in_wordnet)
for word in lemmas_in_WordNet:
   print word
# Out:
# fawn
# european_creeper
# female_child
# sir_frederick_handley_page
# taconic_mountains
# nunnery
# peroxide_blonde
# composite_number
# utnapishtim
# long_wave
# sultanate_of_oman
# gaius_aurelius_valerius_diocletian
# circuitry
# clotted
# xerophthalmus
# fabianism
# impermanence
# woody
# manganese_steel
# self-reliant
# rockingham_podocarp
# localized
# spidery
# regularize
# genus_madoqua
# jacques_cartier
# il_duce
# fibrillose
# turn_one's_stomach
# italian_rice
# niccolo_paganini
# turn_thumbs_down
# sack_out
# macrotis_lagotis
# ringworm_bush
# trial_and_error
# ni-hard
# range_pole
# crossbar
# twilight_of_the_gods
# rumbustious
# rosidae
# bioclimatology
# family_dacninae
# heliothis
# june_21
# touristed
# slothful
# june_24
# june_29
# black_pepper
# pigment
# republic_of_zambia
# transvestism
# fourth_power
# manilkara_zapota
# ploceidae
# screaming
# aporocactus
# wooded
# lithiasis
# simple_interest
# grueling
# vibrational
# wooden
# wholemeal
# understock
# ...
